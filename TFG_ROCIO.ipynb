# %% [markdown]
# <a href="https://colab.research.google.com/github/rpacheco-blazquez/tfe-tfg-rocio-fernandez-ortega/blob/main/TFG_ROCIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6kWwwWh1CzC3j30jns9P")
project = rf.workspace("tfg-5rnd2").project("tfg_rocio")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s-pose.pt")

model.train(
    data="/content/TFG_Rocio-2/data.yaml",
    epochs=50,
    imgsz=640,
    task="pose",
    project="/content/drive/MyDrive/TFG_Rocio-2_resultados",
    name="train"
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from google.colab import files
files.download('/content/runs/pose/train/weights/best.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3054988160.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('/content/runs/pose/train/weights/best.pt')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/runs/pose/train/weights/best.pt

# %%
import os
# Buscar todos los archivos .pt que se hayan generado
# !find /content -name "*.pt" 2>/dev/null
# Out:
# /content/yolov8s-pose.pt
# /content/drive/MyDrive/TFG_Rocio-2_resultados/train/weights/last.pt
# /content/drive/MyDrive/TFG_Rocio-2_resultados/train/weights/best.pt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# ...

# %%
import os
print(os.path.exists('/content/drive/MyDrive/TFG_Rocio-2_resultados/train/weights/best.pt'))
# Out:
# True

# %%
from google.colab import files
files.download('/content/drive/MyDrive/TFG_Rocio-2_resultados/train/weights/best.pt')
