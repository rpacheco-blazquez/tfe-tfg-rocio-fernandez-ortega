# %% [markdown]
# <a href="https://colab.research.google.com/github/rpacheco-blazquez/tfe-tfg-rocio-fernandez-ortega/blob/main/TFG_ROCIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6kWwwWh1CzC3j30jns9P")
project = rf.workspace("tfg-5rnd2").project("tfg_rocio")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6kWwwWh1CzC3j30jns9P")
project = rf.workspace("tfg-5rnd2").project("tfg_rocio")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

# %%
model.train(data="/content/TFG_Rocio-1/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6kWwwWh1CzC3j30jns9P")
project = rf.workspace("tfg-5rnd2").project("tfg_rocio")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to TFG_Rocio-2 in yolov8:: 100%|██████████| 71/71 [00:00<00:00, 6980.51it/s]

# %%
model.train(data="/content/TFG_Rocio-2/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
model = YOLO("yolov8s-pose.pt")

model.train(data="/content/TFG_Rocio-2/data.yaml", epochs=100, imgsz=640, task="pose")
# Out:
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
import os

labels_dir = "/content/TFG_Rocio-2/train/labels"

for filename in os.listdir(labels_dir):
    if filename.endswith(".txt"):
        filepath = os.path.join(labels_dir, filename)
        with open(filepath, "r") as f:
            lines = f.readlines()

        new_lines = []
        for line in lines:
            values = line.strip().split()
            new_values = [values[0]]
            for v in values[1:]:
                num = float(v)
                num = max(0.0, min(1.0, num / 2))
                new_values.append(f"{num:.6f}")
            new_lines.append(" ".join(new_values) + "\n")

        with open(filepath, "w") as f:
            f.writelines(new_lines)

print("Etiquetas corregidas")
# Out:
# Etiquetas corregidas

# %%
import os

cache = "/content/TFG_Rocio-2/train/labels.cache"
if os.path.exists(cache):
    os.remove(cache)
    print("Caché eliminado")

model.train(data="/content/TFG_Rocio-2/data.yaml", epochs=100, imgsz=640, task="pose")
# Out:
# Caché eliminado
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
model.train(data="/content/TFG_Rocio-2/data.yaml", epochs=50, imgsz=640, task="pose")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1801804030.py in <cell line: 0>()
# ----> 1 model.train(data="/content/TFG_Rocio-2/data.yaml", epochs=50, imgsz=640, task="pose")
#
# NameError: name 'model' is not defined

# %%
from ultralytics import YOLO
model = YOLO("yolov8s-pose.pt")

# %%
model.train(data="/content/TFG_Rocio-2/data.yaml", epochs=50, imgsz=640, task="pose")
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
